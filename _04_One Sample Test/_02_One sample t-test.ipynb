# %% [markdown]
# # T-test

# %% [markdown]
# ## Conditions for t-test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Critical Test Statistic

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Degrees of freedom (df) = n-1
#
# In this example, n = 4 (we randomly picked 4 bottles for testing)

# %% [markdown]
# ## Interpret the Results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### One sample t-Test using Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
volume = pd.Series([148.5,153.4,150.9,151.2])

# %%
volume
# Out:
# 0    148.5
# 1    153.4
# 2    150.9
# 3    151.2
# dtype: float64

# %%
volume.describe()
# Out:
# count      4.000000
# mean     151.000000
# std        2.004994
# min      148.500000
# 25%      150.300000
# 50%      151.050000
# 75%      151.750000
# max      153.400000
# dtype: float64

# %%
import scipy.stats as stats

# %%
stats.ttest_1samp(a=volume,popmean=150)
# Out:
# Ttest_1sampResult(statistic=0.997509336107632, pvalue=0.3920333832606524)
